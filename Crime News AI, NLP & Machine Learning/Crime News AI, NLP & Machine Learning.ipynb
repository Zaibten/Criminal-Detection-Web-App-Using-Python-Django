# %% [markdown]
# # Crime News AI, NLP & Machine Learning

# %%
pip install newsapi-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsapi.newsapi_client import NewsApiClient

# %%
pip install requests pandas
# Out:
# ...
#
# ...

# %%
import pprint
import requests
import pandas as pd
from pandas import json_normalize

# %%
url = 'https://newsapi.org/v2/everything?'

# %%
#1#robbery
parameters = {
    'q':'robbery AND (manhattan) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    #'sources' : 'abc-news,cbs-news,cnn,fox-news,msnbc,nbc-news,new-york-magazine,usa-today,the-washington-post,cnbc,espn,google-news,ign,techcrunch,reuters,newsweek,the-american-conservative',
    'pageSize': 90,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29',
    'page':1
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'info@hypebeast.com (Hypebeast)',
#                'content': 'This year, the art world was filled with dramatic, '
#                           'boundary-pushing moments that captured global '
#                           'attention. From environmental activists making bold '
#                           'statements on historic landmarks to record-breakin… '
#                           '[+5258 chars]',
#                'description': 'This year, the art world was filled with '
#                               'dramatic, boundary-pushing moments that '
#                               'captured global attention. From environmental '
#                               'activists making bold statements on historic '
#                               'landmarks to record-breaking auction sales, the '
#                               'cultural landscape has been anything bu…',
#                'publishedAt': '2024-12-23T15:09:06Z',
# ...

# %%
#2 rape#
parameters = {
    'q':'rape (manhattan) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 90,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'John L. Dorman',
#                'content': 'ABC News will pay $15 million toward '
#                           "President-elect Donald Trump's future presidential "
#                           'library.Chip Somodevilla/Getty Images\r\n'
#                           '<ul><li>ABC News settled a defamation lawsuit filed '
#                           'by Trump for $15 mil… [+1710 chars]',
#                'description': 'Trump filed a defamation lawsuit over '
#                               'inaccurate comments made by the anchor George '
#                               "Stephanopoulos on a March episode of ABC's "
#                               '"This Week."',
#                'publishedAt': '2024-12-14T21:47:15Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': "ABC News will pay $15 million to Trump's future "
#                         'presidential library to settle defamation suit',
# ...

# %% [raw]
# #3 blackmail
# parameters = {
#     'q':'blackmail AND(bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-01-29',
#     'page':1
#
# }
#
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %%
#4.theft
parameters = {
    'q':'theft AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29'
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Burton S. Blumert',
#                'content': 'I was born (a few months before the Crash) at 4:20 '
#                           'PM on February 11, 1929, in the Crotona Park '
#                           'Hospital, the Bronx, New York. My mother: a pert '
#                           '20-year-old, my father, 26, a bon vivant. Both were '
#                           'homegrown New Yorkers, and I would be an only '
#                           'child. From a po… [+8576 chars]',
#                'description': 'I was born (a few months before the Crash) at '
#                               '4:20 PM on February 11, 1929, in the Crotona '
#                               'Park Hospital, the Bronx, New York. My mother: '
#                               'a pert 20-year-old, my father, 26, a bon '
#                               'vivant. Both were homegrown New Yorkers, and I '
#                               'would be an only child. From a po…',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\theft.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\theft.csv

# %%
#5. muder
parameters = {
    'q':'murder AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'unewsy',
#                'content': 'FILE - President Donald Trump speaks in the Oval '
#                           'Office of the White House, Friday, April 10, in '
#                           'Washington.(Evan Vucci/AP) President...',
#                'description': 'An ex-convict with a history of drug arrests '
#                               'dating to the late 80s has been charged with '
#                               'the fatal shooting of a Bronx man last month, '
#                               'cops said Monday.',
#                'publishedAt': '2020-04-21T13:08:01Z',
#                'source': {'id': None, 'name': 'Mr-mehra.com'},
#                'title': 'Ex-con busted in drug-related Bronx murder',
#                'url': 'http://www.mr-mehra.com/2020/04/ex-con-busted-in-drug-related-bronx.html',
# ...

# %%
#6.burglary
parameters = {
    'q':'burglary AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 100,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29',
    'page':1
    
}
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Ruth Weissmann',
#                'content': 'Cops busted a Bronx burglar early Saturday who was '
#                           'trying to hide under the cover of darkness but was '
#                           'nabbed after aviation units spied him with thermal '
#                           'imaging cameras, officials said.\r\n'
#                           'Carl Summers, 56, broke a window at the United '
#                           'Cerebral Palsy school on … [+794 chars]',
#                'description': 'Cops busted a Bronx burglar early Saturday who '
#                               'was trying to hide under the cover of darkness '
#                               '— but was nabbed after aviation units spied him '
#                               'with thermal imaging cameras, officials said. '
#                               'Carl Summers, 56, broke a window at the United '
#                               'Cerebral Palsy school on…',
# ...

# %% [raw]
# #7.Kidnapping
# parameters = {
#     'q':'kidnapping AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-1-29',
#     'page':1
#
# }
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %% [raw]
# data = response_json.get("articles")
#
# df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
# filename = 'E:\\new-api-raw-data\\kidnapping.csv'
# print(filename)
# df.to_csv (filename, index = False, header=True)

# %%
#8.drug
parameters = {
    'q':'drug AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-01-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'gmaddaus',
#                'content': 'An anonymous woman sued Moroccan-American rapper '
#                           'French Montana on Thursday, alleging that she was '
#                           'given alcohol and raped during a party at the '
#                           'artist’s home in Hidden Hills, Calif. two years '
#                           'ago.\r\n'
#                           'The woman — identified only as Jane Doe — states '
#                           'that she bl… [+2379 chars]',
#                'description': 'An anonymous woman sued Moroccan-American '
#                               'rapper French Montana on Thursday, alleging '
#                               'that she was given alcohol and raped during a '
#                               'party at the artist’s home in Hidden Hills, '
#                               'Calif. two years ago. The woman — identified '
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\drug.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\drug.csv

# %%
#9. arson
#parameters = {
#    'q':'arson AND (bronx OR manhatten OR brooklyn OR queens OR Staten) NOT (covid-19 OR coronavirus)', 
#    'pageSize': 50,  # maximum is 100
 #   'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#    'from_param':'2020-1-29',
#    'page':1
    
#}

#response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
#response_json = response.json()
#pprint.pprint(response_json)

# %%
#data = response_json.get("articles")

#df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
#filename = 'E:\\new-api-raw-data\\arson.csv'
#print(filename)
#df.to_csv (filename, index = False, header=True)

# %% [raw]
# #larceny
# parameters = {
#     'q':'larceny AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-1-29',
#     'page':1
#
# }
#
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %% [raw]
# data = response_json.get("articles")
#
# df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
# filename = 'E:\\new-api-raw-data\\larceny.csv'
# print(filename)
# df.to_csv (filename, index = False, header=True)

# %%
#11.assault
parameters = {
    'q':'assault AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'gmaddaus',
#                'content': 'An anonymous woman sued Moroccan-American rapper '
#                           'French Montana on Thursday, alleging that she was '
#                           'given alcohol and raped during a party at the '
#                           'artist’s home in Hidden Hills, Calif. two years '
#                           'ago.\r\n'
#                           'The woman — identified only as Jane Doe — states '
#                           'that she bl… [+2379 chars]',
#                'description': 'An anonymous woman sued Moroccan-American '
#                               'rapper French Montana on Thursday, alleging '
#                               'that she was given alcohol and raped during a '
#                               'party at the artist’s home in Hidden Hills, '
#                               'Calif. two years ago. The woman — identified '
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\assault.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\assault.csv

# %%
#smuggling
parameters = {
    'q':'smuggling AND (bronx) NOT (novel OR movie OR netflix OR wiki OR film OR tv OR pandemic OR covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Paul Flannery',
#                'content': 'From ‘Ball Four’ to ‘Out of Sight’, here are a few '
#                           'books you can come back to over and over again I '
#                           'love my books. They have traveled with me across '
#                           'the country and back again, prominently displayed '
#                           'in cheap bookcases throughout dozens of apartments '
#                           'around th… [+9327 chars]',
#                'description': 'From ‘Ball Four’ to ‘Out of Sight’, here are a '
#                               'few books you can come back to over and over '
#                               'again',
#                'publishedAt': '2020-04-22T14:00:00Z',
#                'source': {'id': None, 'name': 'Sbnation.com'},
#                'title': '24 great books for quarantined sports fans',
#                'url': 'https://www.sbnation.com/2020/4/22/21230114/quarantine-reading-list',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\smuggling.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\smuggling.csv

# %% [raw]
# # perjury
# parameters = {
#     'q':'perjury AND (queens) NOT (covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-1-29',
#     'page':1
#
# }
#
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %% [raw]
# data = response_json.get("articles")
#
# df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
# filename = 'E:\\new-api-raw-data\\perjury.csv'
# print(filename)
# df.to_csv (filename, index = False, header=True)

# %%
#shooting

parameters = {
    'q':'shooting AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Mat Paget',
#                'content': "Ubisoft has kicked off a brand-new sale that's full "
#                           "of its best digital PC games. Whether you're "
#                           "skulking the hallways of your squad's objective in "
#                           'Rainbow Six Siege, fighting for the freedom of '
#                           'Washington and New York in The Division 2, or '
#                           'assassinating badd… [+2532 chars]',
#                'description': "Ubisoft has kicked off a brand-new sale that's "
#                               'full of its best digital PC games. Whether '
#                               "you're skulking the hallways of your squad's "
#                               'objective in Rainbow Six Siege, fighting for '
#                               'the freedom of Washington and New York in The '
#                               'Division 2, or assassinating badd…',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\shooting.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\shooting.csv

# %%
parameters = {
    'q':'manslaughter AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Kaelen Wilson-Goldie',
#                'content': 'OVER THE PAST THIRTY YEARS, the artist Moyra Davey '
#                           'has made ten ever more luminous and ambitious '
#                           'films. Each of them is at once a work of continuity '
#                           'and rupture, from the quirky Hell Notes, 1990, '
#                           'which scours the bedrock of Manhattan and loops '
#                           'around the isla… [+20231 chars]',
#                'description': 'OVER THE PAST THIRTY YEARS, the artist Moyra '
#                               'Davey has made ten ever more luminous and '
#                               'ambitious films. Each of them is at once a work '
#                               'of continuity and rupture, from the quirky Hell '
#                               'Notes, 1990, which scours the bedrock of '
#                               'Manhattan and loops around the isla…',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\manslaughter.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\manslaughter.csv

# %%
parameters = {
    'q':'bribery AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Associated Press',
#                'content': '(LOS ANGELES) — The U.S. has returned $300 million '
#                           'to Malaysia that prosecutors say was stolen in a '
#                           'multibillion-dollar corruption scheme, authorities '
#                           'announced Tuesday.\r\n'
#                           'The money comes from assets forfeited last year by '
#                           'a financier, Jho Low, in a Los Angele… [+1946 '
#                           'chars]',
#                'description': 'The U.S. has returned $300 million to Malaysia '
#                               'that prosecutors say was stolen in a '
#                               'multibillion-dollar corruption scheme',
#                'publishedAt': '2020-04-15T02:24:38Z',
#                'source': {'id': 'time', 'name': 'Time'},
#                'title': 'U.S. Returns Another $300 Million in Recovered Funds '
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\bribery.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\bribery.csv

# %% [raw]
# parameters = {
#     'q':'cybercrime AND (bronx) NOT (covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-1-29',
#     'page':1
#
# }
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %% [raw]
# data = response_json.get("articles")
#
# df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
# filename = 'E:\\new-api-raw-data\\cybercrime.csv'
# print(filename)
# df.to_csv (filename, index = False, header=True)

# %%
parameters = {
    'q':'homicide AND (manhattan) NOT (coronavirus OR covid-19)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Léa Bodin',
#                'content': 'De "Treme", qui fête ses 10 ans, à "The Plot '
#                           'Against America", dont la diffusion est encore en '
#                           'cours, les sept séries de David Simon sont '
#                           'disponibles sur OCS : un univers à découvrir '
#                           'absolument. Voilà pourquoi.Blown Deadline '
#                           'Productions\r\n'
#                           "Aujourd'hui, Treme, l… [+12770 chars]",
#                'description': 'De "Treme", qui fête ses 10 ans, à "The Plot '
#                               'Against America", dont la diffusion est encore '
#                               'en cours, les sept séries de David Simon sont '
#                               'disponibles sur OCS : un univers à découvrir '
#                               "absolument. Voilà pourquoi. >> Lire l'article | "
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\homicide.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\homicide.csv

# %% [markdown]
# #parameters = {
#     'q':'sexual AND (bronx OR manhatten OR brooklyn OR queens OR Staten) NOT (covid-19 OR coronavirus)',
#     'pageSize': 50,  # maximum is 100
#     'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
#     'from_param':'2020-1-29',
#     'page':1
#
# }
#
# response = requests.get(url, params=parameters)
#
# # Convert the response to JSON format and pretty print it
# response_json = response.json()
# pprint.pprint(response_json)

# %% [markdown]
# # data = response_json.get("articles")
#
# df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
# filename = 'E:\\new-api-raw-data\\sexual.csv'
# print(filename)
# df.to_csv (filename, index = False, header=True)

# %%
#Identity Theft
parameters = {
    'q':'Crime AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Doreen St. Félix',
#                'content': 'Who deserves the directing credit for Tiger King: '
#                           'Murder, Mayhem and Madness, which, in the long last '
#                           'week of March, became Netflixs most popular title? '
#                           'The answer isnt straightforward. True, it was the '
#                           'documentarians Eric Goode and Rebecca Chailkin, '
#                           'along wi… [+8101 chars]',
#                'description': 'Doreen St. Félix reviews the hit Netflix '
#                               'true-crime series, which revels in its '
#                               'subjects, human beasts and their prey.',
#                'publishedAt': '2020-04-06T10:00:00Z',
#                'source': {'id': None, 'name': 'Newyorker.com'},
#                'title': 'The Crass Pleasures of “Tiger King”',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\Crime.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\Crime.csv

# %%
parameters = {
    'q':'imprisonment AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Nathaniel Rich',
#                'content': 'Simon and Schuster, 341 pp., $28.00\r\n'
#                           'P.T. Barnum; drawing by Tom Bachtell\r\n'
#                           'Since his heyday in the mid-nineteenth century, '
#                           'P.T. Barnum’s name has been shorthand for ebullient '
#                           'humbuggery, maximalist entertainment, inexhaustible '
#                           'self-promotion, rags-to-riches i… [+18964 chars]',
#                'description': 'Since his heyday in the mid-nineteenth century, '
#                               'P.T. Barnum’s name has been shorthand for '
#                               'ebullient humbuggery, maximalist entertainment, '
#                               'inexhaustible self-promotion, rags-to-riches '
#                               'industriousness—for fun. Yet the images that '
#                               'animate his biographies are uni…',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\imprisonment.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\imprisonment.csv

# %%
parameters = {
    'q':'stalking AND (manhattan) NOT (covid-19 OR coronavirus)', 
    'pageSize': 50,  # maximum is 100
    'apiKey': 'f85e94c0729b42b3a16589ba75ea27ea',
    'from_param':'2020-1-29',
    'page':1
    
}

response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Cheryl Eddy',
#                'content': 'Wed be excited for the return of What We Do in the '
#                           'Shadows no matter what. But given the bleak state '
#                           'of the world, getting reacquainted with the shows '
#                           'awkwardly hilarious vampire roommates felt like an '
#                           'especially welcome distraction. Last nights '
#                           'two-episode s… [+4436 chars]',
#                'description': 'We’d be excited for the return of What We Do in '
#                               'the Shadows no matter what. But given the bleak '
#                               'state of the world, getting reacquainted with '
#                               'the show’s awkwardly hilarious vampire '
#                               'roommates felt like an especially welcome '
#                               'distraction. Last night’s two-episod…',
# ...

# %%
data = response_json.get("articles")

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')
filename = 'E:\\new-api-raw-data\\stalking.csv'
print(filename)
df.to_csv (filename, index = False, header=True)
# Out:
# E:\new-api-raw-data\stalking.csv

# %%
import os
import glob
import pandas as pd
os.chdir("E:/new-api-raw-data")

# %%
extension = 'csv'
all_files= [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_files])
#export to csv
combined_csv.to_csv( "Manhattan.csv", index=False)

# %%
from newsapi.newsapi_client import NewsApiClient
